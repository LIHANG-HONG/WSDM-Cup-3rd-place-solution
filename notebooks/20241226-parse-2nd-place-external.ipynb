# %% [markdown]
# # Excute the capypara.py, rlhflow1.py, rlhflow2.py in scripts folder first

# %%
import pandas as pd
from tqdm.auto import tqdm
import glob

# %%
fs = glob.glob('../scripts/other-external/*')
dfs = []
for f in tqdm(fs):
    df = pd.read_csv(f)
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#                                              id  model_a  model_b  \
# 0       RLHFlow/Helpsteer-preference-standard-0  unknown  unknown
# 1       RLHFlow/Helpsteer-preference-standard-1  unknown  unknown
# 2       RLHFlow/Helpsteer-preference-standard-2  unknown  unknown
# 3       RLHFlow/Helpsteer-preference-standard-3  unknown  unknown
# 4       RLHFlow/Helpsteer-preference-standard-4  unknown  unknown
# ...                                         ...      ...      ...
# 131978  RLHFlow/PKU-SafeRLHF-30K-standard-26869  unknown  unknown
# 131979  RLHFlow/PKU-SafeRLHF-30K-standard-26870  unknown  unknown
# 131980  RLHFlow/PKU-SafeRLHF-30K-standard-26871  unknown  unknown
# 131981  RLHFlow/PKU-SafeRLHF-30K-standard-26872  unknown  unknown
# 131982  RLHFlow/PKU-SafeRLHF-30K-standard-26873  unknown  unknown
#
#                                                    prompt  \
# 0       ["What are the three most important things to ...
# ...

# %%
import json
def transfer_prompt(x):
    x = json.loads(x)
    x = [xx for xx in x if xx is not None]
    x = ' '.join(x)
    return x

# %%
df['prompt'] = df['prompt'].apply(transfer_prompt)
df['response_a'] = df['response_a'].apply(transfer_prompt)
df['response_b'] = df['response_b'].apply(transfer_prompt)

# %%
df['author'] = df['id'].apply(lambda x: '-'.join(x.split('-')[:-1]))

# %%
df.to_parquet('../data/2nd_place_external.parquet')
