# %%
import pandas as pd
kc = pd.read_csv('lmsys-33k.csv')
kc.drop_duplicates(subset=['id','winner_model_a','winner_model_b','winner_tie'])
# Out:
#                                      id            model_a            model_b  \
# 0      58210e39b3fd4441a2bd4a518bb44c2d         chatglm-6b          koala-13b
# 1      2564acd09e3942fd97657d05282d4389   oasst-pythia-12b         alpaca-13b
# 2      90bfd142157948aba01931726c888e7f          koala-13b   oasst-pythia-12b
# 3      a7c5accc53e649a3bc6b2e41d962ebc4         vicuna-13b   oasst-pythia-12b
# 4      adf27e819a3c494cb6e993f0c660e097         vicuna-13b          koala-13b
# ...                                 ...                ...                ...
# 32995  8777c4945d85469d96cd26fc2ea6f64a         alpaca-13b  claude-instant-v1
# 32996  86063a921be548989c55b85497ab009a  claude-instant-v1        guanaco-33b
# 32997  6685a3b3863f4554887e432f7dbbe8a5       wizardlm-13b   oasst-pythia-12b
# 32998  f72930b382e949ea879e7abf3cb1e587        guanaco-33b          koala-13b
# 32999  a147958b2bd049229facdbffa72a4662         chatglm-6b       wizardlm-13b
#
# ...

# %%
import pandas as pd
kk = pd.read_csv('lmsys-33k.csv')
bb = pd.read_csv('LMSYS2/train.csv')
bb['author'] = 'lmsys1'
kk['author'] = 'lmsys1_external'
bb['id'] = bb['id'].astype(str)
kk['id'] = kk['id'].astype(str)
kk = kk.drop_duplicates(subset=['prompt','model_a','model_b','winner_model_a', 'winner_model_b', 'winner_tie']).reset_index(drop=True)

# %%
from ast import literal_eval
ck = pd.concat([bb,kk]).reset_index(drop=True)

# %%
def transfer_prompt(x):
    x = json.loads(x)
    x = [xx for xx in x if xx is not None]
    x = ' '.join(x)
    return x

# %%
import json
ck['prompt'] = ck['prompt'].apply(transfer_prompt)
ck['response_a'] = ck['response_a'].apply(transfer_prompt)
ck['response_b'] = ck['response_b'].apply(transfer_prompt)
ck['language'] = 'English'

# %%
ck
# Out:
#                                      id             model_a  \
# 0                                 30192  gpt-4-1106-preview
# 1                                 53567           koala-13b
# 2                                 65089  gpt-3.5-turbo-0613
# 3                                 96401    llama-2-13b-chat
# 4                                198779           koala-13b
# ...                                 ...                 ...
# 90398  8777c4945d85469d96cd26fc2ea6f64a          alpaca-13b
# 90399  86063a921be548989c55b85497ab009a   claude-instant-v1
# 90400  6685a3b3863f4554887e432f7dbbe8a5        wizardlm-13b
# 90401  f72930b382e949ea879e7abf3cb1e587         guanaco-33b
# 90402  a147958b2bd049229facdbffa72a4662          chatglm-6b
#
#                    model_b                                             prompt  \
# 0               gpt-4-0613  Is it morally right to try to have a certain p...
# 1               gpt-4-0613  What is the difference between marriage licens...
# ...

# %%
tt = pd.read_parquet('train.parquet')

# %%
tt['winner_model_a'] = tt['winner'].apply(lambda x: int(x=='model_a'))
tt['winner_model_b'] = tt['winner'].apply(lambda x: int(x=='model_b'))
tt['winner_tie'] = 0
tt = tt.drop(columns=['winner'],axis=1)
tt['author'] = 'lmsys2'
tt
# Out:
#                                                       id  \
# 0      00007cff95d7f7974642a785aca248b0f26e60d3312fac...
# 1      00010ed04b536f56ebe43eef1100c13906abea12bf9855...
# 2      0003800d510e38803efba5ceaec122bc66408fe367b0be...
# 3      00072026c68f5418ef2da238394e418ce72a534b9b22d5...
# 4      0007ce7cf6bc1b5a8f8a4669b854fb12030863c970d9dc...
# ...                                                  ...
# 48434  fff5962462043091a771018e37ece11c425e9c7cca64b2...
# 48435  fffad6c95fb82e3a694b4952965852130285e0a38905d5...
# 48436  fffbf502f2cd88b706a4bd6e54ed90e9a2d59d1643140d...
# 48437  fffd2ffdaa03e9e0a0cd1e8f2ee80f530bb19b08fa4312...
# 48438  ffff059aea247f1dc7a09cfea55e00309b5b9a2e8cd9fc...
#
#                                                   prompt  \
# 0                                     vieš po Slovensky?
# 1      You will be given a piece of news. Analyze it ...
# 2      Dört basamaklı, rakamları birbirinden ve sıfır...
# ...

# %%
ckt = pd.concat([tt,ck]).reset_index(drop=True)
ckt
# Out:
#                                                        id  \
# 0       00007cff95d7f7974642a785aca248b0f26e60d3312fac...
# 1       00010ed04b536f56ebe43eef1100c13906abea12bf9855...
# 2       0003800d510e38803efba5ceaec122bc66408fe367b0be...
# 3       00072026c68f5418ef2da238394e418ce72a534b9b22d5...
# 4       0007ce7cf6bc1b5a8f8a4669b854fb12030863c970d9dc...
# ...                                                   ...
# 138837                   8777c4945d85469d96cd26fc2ea6f64a
# 138838                   86063a921be548989c55b85497ab009a
# 138839                   6685a3b3863f4554887e432f7dbbe8a5
# 138840                   f72930b382e949ea879e7abf3cb1e587
# 138841                   a147958b2bd049229facdbffa72a4662
#
#                                                    prompt  \
# 0                                      vieš po Slovensky?
# 1       You will be given a piece of news. Analyze it ...
# 2       Dört basamaklı, rakamları birbirinden ve sıfır...
# ...

# %%
ckt = ckt.drop_duplicates(subset=['id'],keep='first').reset_index(drop=True)
ckt
# Out:
#                                                        id  \
# 0       00007cff95d7f7974642a785aca248b0f26e60d3312fac...
# 1       00010ed04b536f56ebe43eef1100c13906abea12bf9855...
# 2       0003800d510e38803efba5ceaec122bc66408fe367b0be...
# 3       00072026c68f5418ef2da238394e418ce72a534b9b22d5...
# 4       0007ce7cf6bc1b5a8f8a4669b854fb12030863c970d9dc...
# ...                                                   ...
# 138822                   8777c4945d85469d96cd26fc2ea6f64a
# 138823                   86063a921be548989c55b85497ab009a
# 138824                   6685a3b3863f4554887e432f7dbbe8a5
# 138825                   f72930b382e949ea879e7abf3cb1e587
# 138826                   a147958b2bd049229facdbffa72a4662
#
#                                                    prompt  \
# 0                                      vieš po Slovensky?
# 1       You will be given a piece of news. Analyze it ...
# 2       Dört basamaklı, rakamları birbirinden ve sıfır...
# ...

# %%
bad_ids = [
    '20cb94a0b7c147fe8fc6250b2a20fd1c',
    'c6192fdbd3dd46c98791d7abac92b56d',
    'a5bd0905ce184926ad6e2c8ac3516fca',
    '0848695dddf64c09a1cdc4edd0e3d2bd',
    'c3a1ad0511084ca68a264ad16fac8bdf',
    '1dd6137eb3c3470989e18ab729ccc0b3',
    '45ca0f7a009943e9b582fd0bb54360d0',
    'f7e1e2963b4e4ed1b551dc6bfc6fd0ae',
    'f10215a74f974d81bce321826e0693cc',
    'c34923a07f514a1a902e96b9ef6400b3',
]
ckt = ckt[ckt['id'].apply(lambda x: x not in bad_ids)].reset_index(drop=True)
ckt
# Out:
#                                                        id  \
# 0       00007cff95d7f7974642a785aca248b0f26e60d3312fac...
# 1       00010ed04b536f56ebe43eef1100c13906abea12bf9855...
# 2       0003800d510e38803efba5ceaec122bc66408fe367b0be...
# 3       00072026c68f5418ef2da238394e418ce72a534b9b22d5...
# 4       0007ce7cf6bc1b5a8f8a4669b854fb12030863c970d9dc...
# ...                                                   ...
# 138812                   8777c4945d85469d96cd26fc2ea6f64a
# 138813                   86063a921be548989c55b85497ab009a
# 138814                   6685a3b3863f4554887e432f7dbbe8a5
# 138815                   f72930b382e949ea879e7abf3cb1e587
# 138816                   a147958b2bd049229facdbffa72a4662
#
#                                                    prompt  \
# 0                                      vieš po Slovensky?
# 1       You will be given a piece of news. Analyze it ...
# 2       Dört basamaklı, rakamları birbirinden ve sıfır...
# ...

# %%
ckt.to_parquet('../data/train_lmsys_all.parquet')
